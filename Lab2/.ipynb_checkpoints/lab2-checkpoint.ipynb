# %% [markdown]
# <center>
# <h1>Rana Fahad Aman</h1>
# <h3>Artificial Intelligence Lab_2</h3>
# <h4>14 September 2023</h4>
# </center>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# <center><h4>Pre Lab Task 1</h4></center>

# %%
values = np.random.randint(25,size=100)
plt.plot(values)
plt.title("Random Values Plot")
plt.xlabel("Index")
plt.xlim(0,25)
plt.ylim(-5,25)
plt.ylabel("Values")
plt.show()

# %% [markdown]
# <center>
#     <h4>In Lab Task 1</h4>
#     <h4>{Using Line Breaks}</h4>
# </center>

# %%
print("Hello World!\nMy name is Rana Fahad Aman.\nMy Registration is FA20-BCE-021.\nThis is my first AI Lab.")
# Out:
# Hello World!
# My name is Rana Fahad Aman.
# My Registration is FA20-BCE-021.
# This is my first AI Lab.

# %% [markdown]
# <center>
#     <h4>In Lab Task 2</h4>
#     <h4>{Cell Creation}</h4>
# <em>This was the 'Cell Creation using #%%' task, so wasn't applicable in Jupyter Lab, only in Spyder.</em></center>

# %% [markdown]
# <center><h4>In Lab Task 3</h4>
#     <h4>{Logical Operators}</h4>
# </center>

# %%
x = 1
if x == 1:
    print("x is 1")
else:
    print("x is not 1")
# Out:
# x is 1

# %% [markdown]
# <center><h4>In Lab Task 4</h4>
#     <h4>{Data Types}</h4>
# </center>

# %%
x = 21
print(f"The type of x is {type(x)}")
# Out:
# The type of x is <class 'int'>

# %%
x = 21.0
print(f"The type of x is {type(x)}")
# Out:
# The type of x is <class 'float'>

# %%
x = 21.0
print(f"The type of x is {type(x)}")
x_integer = int(x)
print(f"The type of x is {type(x_integer)}")
# Out:
# The type of x is <class 'float'>
# The type of x is <class 'int'>

# %%
x = "FA20-BCE-021"
print(f"The type of x is {type(x)}")
# Out:
# The type of x is <class 'str'>
