# %%
import matplotlib.pyplot as plt

# %%
cgpaPlot = [3.28,3.14,3.09,2.88,3.10,3.14]
plt.plot(cgpaPlot)
plt.title("GPA Plot")
plt.xlabel("Semester Number")
plt.ylabel("CGPA")
#plt.xlim(1,7)
#plt.ylim(2.5,4.0)
plt.show()
