# %% [markdown]
# <center>
#     <h1>Rana Fahad Aman {FA20-BCE-021}</h1>
#     <h3></h3>
# <h4>
#     CGPA Plot {Assigned Task}
# </h4>
# </center>

# %% [markdown]
# ## CGPA Plot

# %%
import matplotlib.pyplot as plt

# %%
cgpaPlot = [3.28,3.14,3.09,2.88,3.10,3.14]
plt.plot(cgpaPlot)
plt.title("CGPA Plot")
plt.xlabel("Semester Number")
plt.ylabel("CGPA")
#plt.xlim(1,7)
#plt.ylim(2.5,4.0)
plt.show()
